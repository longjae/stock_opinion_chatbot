# %%
import requests
from bs4 import BeautifulSoup
import pdfplumber
import re
import os
import pymongo
import time
import random
from dotenv import load_dotenv

# %%
load_dotenv()

MONGO_URI = os.getenv("MONGO_URI")
DATABASE_NAME = os.getenv("DATABASE_NAME")
COLLECTION_NAME = os.getenv("COLLECTION_NAME")

client = pymongo.MongoClient(MONGO_URI)
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# %%
def extract_text_from_pdf(pdf_url):
    """PDF URL에서 텍스트 추출"""
    try:
        response = requests.get(pdf_url)
        response.raise_for_status()

        if not os.path.exists("./temp"):
            os.makedirs("./temp")

        with open("./temp/temp.pdf", "wb") as f:
            f.write(response.content)

        with pdfplumber.open("./temp/temp.pdf") as pdf:
            text = "".join([page.extract_text() for page in pdf.pages])

        return text

    except requests.exceptions.RequestException as e:
        print(f"PDF 다운로드 에러: {e}")
        return None
    except Exception as e:
        print(f"PDF 텍스트 추출 중 에러 발생: {e}")
        return None

# %%
def extract_report_data(report_url):
    """리포트 URL에서 PDF URL을 추출하고, PDF 내용을 추출하여 반환"""
    try:
        pdf_url = report_url
        return extract_text_from_pdf(pdf_url)

    except requests.exceptions.RequestException as e:
        print(f"Request 에러: {e}")
        return None
    except Exception as e:
        print(f"리포트 데이터 추출 중 에러 발생: {e}")
        return None

# %%
def crawl_reports(base_url):
    """리포트 목록 페이지를 크롤링하여 리포트 정보 추출"""
    page_num = 1
    while True:
        url = f"{base_url}&page={page_num}"
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        table = soup.find("table", {"class": "type_1"})

        if not table:
            print("더 이상 리포트가 없습니다.")
            break

        rows = table.find_all("tr")[2:]  # 첫 두 행은 헤더이므로 제외

        if not rows:
            print("더 이상 리포트가 없습니다.")
            break

        for row in rows:
            cells = row.find_all("td")
            # print(cells)

            if not cells or all(cell.text.strip() == "" for cell in cells):
                continue

            company = cells[0].text.strip()
            # print("company:", company)
            title = cells[1].text.strip()
            # print("title:", title)
            report_url = cells[3].find("a")["href"]
            # print("report_url:", report_url)
            brokerage = cells[2].text.strip()
            # print("brokerage:", brokerage)
            date = cells[4].text.strip()
            # print("date:", date)

            report_content = extract_report_data(report_url)
            # print("report_content:", report_content)

            if report_content:
                report_data = {
                    "종목이름": company,
                    "종목코드": "035720",
                    "증권사": brokerage,
                    "제목": title,
                    "날짜": date,
                    "내용": report_content,
                }
                collection.insert_one(report_data)
                print(f"리포트 추출 성공: {title}/{date}")
            else:
                print(f"리포트 내용 추출 실패: {company}:{title}")

            time.sleep(random.uniform(1, 30))
        page_num += 1

# %%
base_url = "https://finance.naver.com/research/company_list.naver?keyword=&brokerCode=&writeFromDate=&writeToDate=&searchType=itemCode&itemName=%C4%AB%C4%AB%BF%C0&itemCode=035720&x=58&y=13"
crawl_reports(base_url)
# Out:
# 리포트 추출 성공: 카톡의 외연 확장 기대
# 리포트 추출 성공: 공개된 전략, 실행과 성과가 중요
# 리포트 추출 성공: AI 메이트 도입으로 코어 비즈니스 가속 시도
# 리포트 추출 성공: 카카오톡 2.0, SNS + AI Agent를 추구
# 리포트 추출 성공: ‘카카오톡+AI’의 청사진, 유저 지표 개선이..
# 리포트 추출 성공: 상승세의 초기 국면
# 리포트 추출 성공: 콘텐츠 부진의 무게가 무겁다
# 리포트 추출 성공: N이라면 상상 가능한 톡의 미래
# 리포트 추출 성공: 상상력을 열게 해준 실적 발표
# 리포트 추출 성공: 오픈AI 협업 발표. AI 네이티브 컴퍼니를 향..
# 리포트 추출 성공: 매니지먼트의 전략적 우위
# 리포트 추출 성공: 저성장 지속과 카카오톡 개편 기대
# 리포트 추출 성공: 성장성 회복이 관건
# 리포트 추출 성공: 톡비즈 성장 개선 정도가 중요
# 리포트 추출 성공: 인공지능 메신저에 대한 기대
# 리포트 추출 성공: 시장 부진 헤쳐 나갈 뾰족한 수 필요
# 리포트 추출 성공: 새로운 카카오톡에 기대를...
# 리포트 추출 성공: 카카오톡의 무거워진 어깨
# 리포트 추출 성공: 플랫폼과 콘텐츠, 각각의 숙제
# 리포트 추출 성공: 체류시간 확대 전략이 무조건 필요
# 리포트 추출 성공: 아직은 뚜렷한 모멘텀 없지만
# 리포트 추출 성공: 잃어버린 성장
# 리포트 추출 성공: 무거워진 본사의 어깨
# 리포트 추출 성공: 신규 원동력이 요구
# 리포트 추출 성공: 외형 성장 둔화로 멀티플 하향 조정
# 리포트 추출 성공: 뼈를 깎고, 살을 취했다
# 리포트 추출 성공: 성장성 둔화 심화
# 리포트 추출 성공: IF 구체화
# 리포트 추출 성공: 다이어트 중
# 리포트 추출 성공: 밋밋한 실적
# 리포트 추출 성공: 돌파구가 필요
# 리포트 추출 성공: 눈에 밟히는 콘텐츠 부진
# 리포트 추출 성공: 새로운 광고 성장 전략 필요
# 리포트 추출 성공: 시작되는 비핵심 사업 축소
# 리포트 추출 성공: 자회사 옥석 가리기
# 리포트 추출 성공: 확인이 필요한 시간
# 리포트 추출 성공: 톡비즈 성장 재가속 필요
# 리포트 추출 성공: 하반기 변화 예고
# 리포트 추출 성공: 다이어트 중
# 리포트 추출 성공: 매출 성장 보다는 비용 감축에 기대야
# 리포트 추출 성공: 본업, 자회사 모두 성장률 둔화
# 리포트 추출 성공: 무난한 실적, 무난할 하반기
# 리포트 추출 성공: 둔화되는 성장성
# 리포트 추출 성공: 카카오 주요 자회사 매각 가능성 점검
# 리포트 추출 성공: 저점을 지나가는 구간
# 리포트 추출 성공: 무거워진 어깨
# 리포트 추출 성공: 견조한 톡비즈 vs 제한적인 컨텐츠 성장
# 리포트 추출 성공: 반등의 실마리
# 리포트 추출 성공: 새로운 성장 전략 제시 필요
# 리포트 추출 성공: 컨텐츠 자회사들의 실적 부진 지속
# 리포트 추출 성공: 전략적 의사결정 요구
# 리포트 추출 성공: 이익 개선은 되는데 모멘텀이 부족
# 리포트 추출 성공: 불확실성이 남아 있는 구간
# 리포트 추출 성공: 변화에 유연한 대처로 이익 정상화
# 리포트 추출 성공: 본업의 성장은 확인, AI의 핵심은 서비스화
# 리포트 추출 성공: 경기민감주
# 리포트 추출 성공: 무난한 실적 이후 모멘텀 소멸
# 리포트 추출 성공: AI 투자, 눈에 밟히는 비용
# 리포트 추출 성공: 별도 사업의 어깨가 무거워졌다
# 리포트 추출 성공: 1Q24 Review: 광고 사업 호조 긍정적
# 리포트 추출 성공: 광고 부문 회복세 지속
# 리포트 추출 성공: 쇄신 후 드러날 AI 전략에 초점
# 리포트 추출 성공: 1분기 실적 후 지켜볼 관건은
# 리포트 추출 성공: 1분기 실적 후 지켜볼 관건은
# 리포트 추출 성공: 선방하는 플랫폼
# 리포트 추출 성공: 아쉬운 1분기 실적 예상
# 리포트 추출 성공: 잠시 쉬어가는 1분기
# 리포트 추출 성공: 점점 맞물려가는 톱니바퀴
# 리포트 추출 성공: 탑라인 성장과 비용 컨트롤 효과 극대화
# 리포트 추출 성공: Top과 Bottom 모두 양호했던 실적
# 리포트 추출 성공: 본업의 부활과 높은 멀티플의 상실 사이
# 리포트 추출 성공: 위로는 광고가 붙고 아래로는 손실이 줄고
# 리포트 추출 성공: 쇄신으로 얻은 추진력
# 리포트 추출 성공: 4분기 실적, 2024년의 방향성
# 리포트 추출 성공: 본업 잘하고 비용은 줄이고
# 리포트 추출 성공: 별도가 하드캐리
# 리포트 추출 성공: 더 좋아진 톡비즈
# 리포트 추출 성공: 실적은 오히려 좋았다
# 리포트 추출 성공: 이번 실적은 24년 서프라이즈의 예고편
# 리포트 추출 성공: 가벼워진 몸으로 올해 새 출발
# 리포트 추출 성공: 다시 이익 성장기로 진입
# 리포트 추출 성공: 외부 노이즈가 막지 못한 실적 성장
# 리포트 추출 성공: 톡비즈에 힘쓴 보람
# 리포트 추출 성공: 변화와 기대에 대한 검증 필요
# 리포트 추출 성공: 외부변수 제외하고 보아도 높은 성장
# 리포트 추출 성공: 2월에도 풍부한 모멘텀 보유
# 리포트 추출 성공: 비용 통제와 사업 효율 제고
# 리포트 추출 성공: 재성장을 위한 톡 개편
# 리포트 추출 성공: 3Q23 Review: 보수적 비용 집행 중
# 리포트 추출 성공: 찾았다 희망
# 리포트 추출 성공: 수익성 개선세 지속
# 리포트 추출 성공: 더디지만 나아가는 중
# 리포트 추출 성공: 불확실한 것과 확실한 것
# 리포트 추출 성공: 수익성 개선이 긍정적
# 리포트 추출 성공: 성장통을 겪는 중
# 리포트 추출 성공: 내부 정비를 통한 회복 필요
# 리포트 추출 성공: 톡비즈 성장률 회복이 관건
# 리포트 추출 성공: 광고 회복세 기대
# 리포트 추출 성공: 아직 더딘 회복 시그널
# 리포트 추출 성공: 게임 부진 & 일회성 비용 따른 컨센 하회 전..
# 리포트 추출 성공: 톡 개편과 헬스케어로 성장 모색
# 리포트 추출 성공: 2023년 애널리스트 데이 Key Takeaways
# 리포트 추출 성공: 언제살까?
# 리포트 추출 성공: 명품도 카카오가 하면 더 잘할수 있다
# 리포트 추출 성공: 구체화된 신성장전략
# 리포트 추출 성공: 2Q23 Review: 비용 효율화 노력
# 리포트 추출 성공: 우려대비 괜찮은 광고
# 리포트 추출 성공: 반가운 트래픽 상승세
# 리포트 추출 성공: 많아진 식구, 무거워진 어깨
# 리포트 추출 성공: 성장성 부재, 자회사 가치 재평가 필요
# 리포트 추출 성공: 하반기 실적 반등은 긍정적, 구체적인 AI 청..
# 리포트 추출 성공: 새로운 성장을 위한 준비
# 리포트 추출 성공: 점진적 우상향을 조망
# 리포트 추출 성공: 재정비의 시간이 필요
# 리포트 추출 성공: 체질 개선의 기간
# 리포트 추출 성공: 투자 확대 사이클을 견뎌내야 하는 시기
# 리포트 추출 성공: 매출과 비용의 동반 성장
# 리포트 추출 성공: 하반기 톡비즈 성장에 달린 주가 회복
# 리포트 추출 성공: 우려보다는 기대를
# 리포트 추출 성공: 경기 반등을 기다리는 카카오톡 개편
# 리포트 추출 성공: AI 사업에서 엇갈린 온도차
# 리포트 추출 성공: 실적 눈높이는 낮추나 하반기 회복기조는 유..
# 리포트 추출 성공: 2분기 컨텐츠, 하반기 톡비즈 반등이 반전 카..
# 리포트 추출 성공: 1Q23 Re: 투자국면
# 리포트 추출 성공: 1Q23 Review: 톡비즈 개편 성과가 중요
# 리포트 추출 성공: 투자 확대 사이클을 견뎌내야 하는 시기
# 리포트 추출 성공: 하반기 본격화될 변화들
# 리포트 추출 성공: 어려운 시장 환경에도 투자는 계속된다
# 리포트 추출 성공: 둔화된 성장
# 리포트 추출 성공: 중장기 긍정적 관점 견지
# 리포트 추출 성공: 전열을 가다듬는 카카오
# 리포트 추출 성공: 사업개편 효과를 증명해야 할 시기
# 리포트 추출 성공: 핵심사업이 빛날 시기
# 리포트 추출 성공: 카카오엔터테인먼트 상장 가시화
# 리포트 추출 성공: 수면 위로 떠오르는 헬스케어 신사업
# 리포트 추출 성공: NDR 후기: 톡비즈 진화에 집중
# 리포트 추출 성공: 사측의 의지치를 높게 평가
# 리포트 추출 성공: 우려보다 양호했던 수익성
# 리포트 추출 성공: 톡비즈 개편은 하반기 실적 기여 예상
# 리포트 추출 성공: 견조한 톡비즈와 비용 절감
# 리포트 추출 성공: 1분기 실적 부진에도 하반기 개선 기대
# 리포트 추출 성공: 수익성 개선이 기대되는 23년
# 리포트 추출 성공: 추웠던 겨울에도 실적은 선방
# 리포트 추출 성공: 경기 침체 영향으로 성장 둔화
# 리포트 추출 성공: 중요한 것은 꺾이지 않는 성장
# 리포트 추출 성공: 골이 깊으면 산도 높다
# 리포트 추출 성공: 실적과 밸류에이션을 점검할 때
# 리포트 추출 성공: 카카오엔터, 1.15조원 규모 유상증자
# 리포트 추출 성공: 선물하기 for 비즈니스의 가능성
# 리포트 추출 성공: 3막을 준비하며
# 리포트 추출 성공: 겨울이 온다
# 리포트 추출 성공: 4분기 실적 개선 제한적일 것
# 리포트 추출 성공: 내년을 위한 숨고르기
# 리포트 추출 성공: 4Q22는 소통과 신뢰 회복의 시기
# 리포트 추출 성공: 예상보다 컸던 브랜딩 광고주의 예산 축소
# 리포트 추출 성공: 거품이 아닌 실력으로. 기대가 아닌 실적으로..
# 리포트 추출 성공: 단기 수익성 악화 불가피
# 리포트 추출 성공: 경기 둔화, 수요 감소 피해가기 힘들 것
# 리포트 추출 성공: 트래픽 회복세 관찰
# 리포트 추출 성공: 서비스 개편 지연 여부 확인 필요
# 리포트 추출 성공: 단기실적보다 우려되는 것은 중장기 성장둔화..
# 리포트 추출 성공: 최악의 구간을 지나서
# 리포트 추출 성공: 이익 반등이 주가 반전의 선결 조건
# 리포트 추출 성공: 매크로 안정화까진 기다림. 몇 가지 포인트는..
# 리포트 추출 성공: 구체화되어가는 광고 성장 전략
# 리포트 추출 성공: 공급이 수요를 창출한다
# 리포트 추출 성공: 하반기 카카오톡 개편 효과 기대
# 리포트 추출 성공: 2Q22 Re: 사업 다변화의 이점
# 리포트 추출 성공: 매크로 환경 영향 마무리?
# 리포트 추출 성공: 벌써 기대되는 4분기 실적
# 리포트 추출 성공: “오픈 채팅” 서비스 가능성 검토
# 리포트 추출 성공: 마진 개선은 내년부터 기대
# 리포트 추출 성공: 비용 지출 지속되는 과도기
# 리포트 추출 성공: 긴 터널을 지나는 중. 언젠가 출구는 나타나..
# 리포트 추출 성공: 2Q22 Pre: 마진 개선은 하반기에
# 리포트 추출 성공: 중장기 성장에 대한 청사진 제시
# 리포트 추출 성공: Analyst Day 후기
# 리포트 추출 성공: 컨텐츠 고성장 기울기 유지 중
# 리포트 추출 성공: 톡비즈 광고 성장 확인 필요
# 리포트 추출 성공: 1Q22 Re: 컨센서스 부합하는 실적
# 리포트 추출 성공: 단기 모멘텀 타이트. 블록체인 경쟁력은 지속..
# 리포트 추출 성공: 2분기 마진 개선 기대
# 리포트 추출 성공: 1Q22 Preview: 상저하고 패턴이 될 것
# 리포트 추출 성공: Klaytn 메인넷의 파워. 블록체인 사업 잠재력..
# 리포트 추출 성공: 플랫폼(톡비즈+신사업) 고성장과 컨텐츠 해외..
# 리포트 추출 성공: 4Q21 Review: 자신감있는 가이던스
# 리포트 추출 성공: 블록체인, 메타버스 등 차세대 신사업 향방 ..
# 리포트 추출 성공: 콘텐츠 중심으로 글로벌 공략 본격화
# 리포트 추출 성공: 방향성, 잠재력 유효. 규제 이슈 안정화까지 ..
# 리포트 추출 성공: 플랫폼 사업 규제 영향 감안, 목표주가 조정
# 리포트 추출 성공: NDR 후기-카카오 성장세는 이제부터 시작
# 리포트 추출 성공: 성공적인 자회사 IPO를 통한 성장
# 리포트 추출 성공: 2Q21 Review: 플랫폼이 이끈 탑라인 성장
# 리포트 추출 성공: 기대를 저버리지 않는 성장성
# 리포트 추출 성공: 2Q21E Preview 및 엔터-멜론 합병 코멘트
# 리포트 추출 성공: 8월 자회사 IPO 이후 카카오 주가를 이끌어갈..
# 리포트 추출 성공: 단기 주가 향방은 하반기 관전포인트는
# 리포트 추출 성공: 카뱅 희망 공모가 기준 시가총액 15.7조~18.5..
# 리포트 추출 성공: 카카오 생태계 한국을 덮다
# 리포트 추출 성공: 일상에서 카카오 서비스의 지배력이 상승한다
# 리포트 추출 성공: 사업 호조, 호재 만발. TP 1 5 액분 기준 조..
# 리포트 추출 성공: 비트코인 열풍 최대 수혜주는 카카오
# 리포트 추출 성공: 일상에서 카카오 서비스의 지배력이 상승한다
# 리포트 추출 성공: 카카오페이지 & 카카오엠 합병, 카카오엔터테..
# 리포트 추출 성공: 2021년 기대감 상향
# 리포트 추출 성공: 2021년 플랫폼 부문이 성장을 견인
# 리포트 추출 성공: 4Q20 실적 QoQ, YoY 대호조 & 컨센서스 부합 ..
# 리포트 추출 성공: 비즈보드, 2021년 돈벼락 예고 중
# 리포트 추출 성공: 브랜드 파워 X 카카오톡 플랫폼 영향력 시너..
# 리포트 추출 성공: 외형 성장 & 이익 개선의 앙상블
# 리포트 추출 성공: 2H20 공격적 마케팅은 투자의 일환
# 리포트 추출 성공: 여전히 성장 구간
# 리포트 추출 성공: 애널리스트 데이 내용 요약
# 리포트 추출 성공: 실적 개선세 지속
# 리포트 추출 성공: 20F 카카오페이지 거래액은 5천억원 이상
# 리포트 추출 성공: 픽코마 일본 잭팟, 웹툰 가치만 10조 이상 가..
# 리포트 추출 성공: 모빌리티, 뱅크 가치 상향 & 픽코마 가치 신..
# 리포트 추출 성공: 프리미엄
# 리포트 추출 성공: Untact 자회사 잠재력 막강. Untact 시대 대..
# 리포트 추출 성공: 최소한 주요 자회사 IPO까지 주가 상승 전망
# 리포트 추출 성공: 코로나19로 인한 암보다 명이 더 크다
# 리포트 추출 성공: 1분기 실적 컨센서스 상회
# 리포트 추출 성공: 큰 그림 확인이 기대되는 1분기 실적 발표
# 리포트 추출 성공: 코로나19로 인한 명과 암이 서로 상쇄
# 리포트 추출 성공: 코로나 19 영향권, 하지만 관전포인트는 유효..
# 리포트 추출 성공: 코로나 19 영향권, 하지만 관전포인트는 유효
# 리포트 추출 성공: 1Q20 숨고르기, but 근본적 부진 아님
# 리포트 추출 성공: 국내 인슈어테크 시장 주도할 전망
# 리포트 추출 성공: 카카오페이의 거침없는 질주
# 리포트 추출 성공: 시총 20 조원 시대 개막
# 리포트 추출 성공: 톡보드 성장세 및 금융 콘텐츠 확장에 주목
# 리포트 추출 성공: 2020년 기대감 또 상승, 목표주가 상향
# 리포트 추출 성공: No Risk!
# 리포트 추출 성공: 진수성찬
# 리포트 추출 성공: 톡비즈보드 매출 4배 증가 가능, 목표주가 상..
# 리포트 추출 성공: 성장성 호조, 수익성 개선. 톡보드 파괴력, ..
# 리포트 추출 성공: 4분기 진짜 실력을 보여줄 시점
# 리포트 추출 성공: 꽃길을 걷는다
# 리포트 추출 성공: 3분기 실적 기대치 상회
# 리포트 추출 성공: 성장성 호조, 수익성 개선. 톡보드 파괴력, ..
# 리포트 추출 성공: SKT와의 지분 제휴로 시너지 효과 기대
# 리포트 추출 성공: 카카오뱅크 유상증자와 대주주 지분 이슈 해..
# 리포트 추출 성공: 증익세 지속될 전망
# 리포트 추출 성공: 톡보드 매출 본격화와 자회사들의 수익성 제..
# 리포트 추출 성공: 3분기 실적 개선의 시작점
# 리포트 추출 성공: 호황(好況)
# 리포트 추출 성공: 본격적인 증익 구간 진입
# 리포트 추출 성공: 수익성 개선 주목. 톡보드, 페이, 뱅크 주목
# 리포트 추출 성공: 광고+커머스의 동반성장, 카카오뱅크 성장 기..
# 리포트 추출 성공: 본격적인 증익 사이클 진입
# 리포트 추출 성공: 톡비즈보드, 카카오뱅크, 카카오페이 동향 주..
# 리포트 추출 성공: 카카오톡, 메신저를 넘어 비즈니스 플랫폼으..
# 리포트 추출 성공: 톡보드 광고매출과 금융서비스 본격화
# 리포트 추출 성공: 카뱅 대주주 가능성은 대형 호재
# 리포트 추출 성공: 톡비즈보드 동향 점검
# 리포트 추출 성공: 카톡 친구탭 광고 노출 본격화 임박
# 리포트 추출 성공: 실적 개선 가시화
# 리포트 추출 성공: 1분기 어닝서프라이즈의 시작
# 리포트 추출 성공: 높은 매출성장성, 비용 컨트롤까지 더해지면
# 리포트 추출 성공: 실적 개선과 풍부한 모멘텀의 완벽한 조화
# 리포트 추출 성공: 턴어라운드의 시발점
# 리포트 추출 성공: 톡비즈보드, 카카오페이 등에서 강력한 모멘..
# 리포트 추출 성공: 생각보다 빠른 실적 개선 속도
# 리포트 추출 성공: 광고 부문의 성장폭 확대와 자회사의 기업가..
# 리포트 추출 성공: 외국인은 2013~4년 페북 랠리를 보았다.
# 리포트 추출 성공: 1Q실적보다는 2Q 광고성장 기대치를 높일 시..
# 리포트 추출 성공: 수면 위로 떠오르다
# 리포트 추출 성공: 궤도에 오르다
# 리포트 추출 성공: 금융결제 인프라 혁신으로 카카오페이 수혜
# 리포트 추출 성공: 4분기 실적, 성장성 확인의 서곡
# 리포트 추출 성공: 높은 매출성장성, 비용 컨트롤까지 더해지면
# 리포트 추출 성공: 2019년 탑라인 성장, 비용 통제 자신
# 리포트 추출 성공: 누이 좋고 매부 좋고
# 리포트 추출 성공: 올해는 OP 대폭 증가 전망. 그리고, 몇 가지 ..
# 리포트 추출 성공: O2O사업 실적 개선과 콘텐츠 사업 모멘텀
# 리포트 추출 성공: 4Q18 Preview: 기대감 많이 낮춰진 상황
# 리포트 추출 성공: 4Q18 Preview: 영업이익 예상치 하회 전망, ..
# 리포트 추출 성공: 2019년 신사업 투자 속도 조절, OPM 관리 예..
# 리포트 추출 성공: Uber IPO → 그럼 한국 시장 15조, 시총 10조
# 리포트 추출 성공: 역전(逆轉)
# 리포트 추출 성공: 예상에 부합한 실적, 내년부터 가시화되는 신..
# 리포트 추출 성공: 중장기 투자종목. 다만, 신사업 투자 속도 조..
# 리포트 추출 성공: 수익성보다 기분 좋은 카카오 광고의 성장성
# 리포트 추출 성공: 견조한 커버리지 확대, 아쉬운 수익성
# 리포트 추출 성공: 신사업 잠재력 감안한 중장기적 관점의 긴 호..
# 리포트 추출 성공: 향후 모멘텀 기다리며
# 리포트 추출 성공: 잰걸음
# 리포트 추출 성공: 자회사들의 의미 있는 변화
# 리포트 추출 성공: 콘텐츠와 핀테크 사업 가치에 주목
# 리포트 추출 성공: 편안한 행보
# 리포트 추출 성공: QoQ 실적 개선과 다양한 모멘텀
# 리포트 추출 성공: 2Q18 Review: 가시화되는 콘텐츠, 생활금융 ..
# 리포트 추출 성공: 실적도 외형 성장성은 Good. 다양한 잠재력 ..
# 리포트 추출 성공: 성장을 위한 투자, 따로 또 같이
# 리포트 추출 성공: 모바일 광고 성장으로 기초체력 향상
# 리포트 추출 성공: 느리지만 개선되는 펀더멘털
# 리포트 추출 성공: 2H18 실적 회복 전망 & 카카오광고, 카카오게..
# 리포트 추출 성공: 하반기 모멘텀을 기대
# 리포트 추출 성공: 카카오M 흡수 합병: 플랫폼, 콘텐츠 독립 전..
# 리포트 추출 성공: 투자, 인건비 확대의 여파가 지속
# 리포트 추출 성공: CEO 변화 첫 해, 신사업 비용 증가세
# Data-loss while decompressing corrupted data
# 리포트 추출 성공: 경주하는 거북이
# 리포트 추출 성공: 확장이 우선
# 리포트 추출 성공: 1Q18은 과도기적 투자 집중 시기. 2Q18부터 ..
# 리포트 추출 성공: 신규사업 성장을 위한 투자의 기간
# 리포트 추출 성공: 여전히 풍부한 모멘텀
# 리포트 추출 성공: 수익 둔화 불가피, 외형 성장에 주목
# 리포트 추출 성공: 부진한 실적에도 풍부한 관전포인트
# 리포트 추출 성공: 1Q18은 투자의 시기. 2Q18부터 모멘텀 강화
# 리포트 추출 성공: 자회사 Monetization으로 주가 상승 기대
# 리포트 추출 성공: 성장을 위한 투자와 Monetization
# 리포트 추출 성공: 올해도 투자의 시기. 신사업/신기술 관련 중..
# 리포트 추출 성공: 모멘텀은 하반기 강세 전망
# 리포트 추출 성공: 외형확대와 질적인 성장
# 리포트 추출 성공: 수익성보다는 성장성에 초점
# 리포트 추출 성공: 유상증자 마무리될 때까지 불확실성 여전. 투..
# 리포트 추출 성공: 모바일 생태계 지배력 강화
# 리포트 추출 성공: 적정가치에 대한 고민
# 리포트 추출 성공: 미래 투자를 위한 유상증자 결정
# 리포트 추출 성공: GDR 발행 결정, 관건은 M&A 대상
# 리포트 추출 성공: 4Q17 OP QoQ (+) 전망. 마케팅비 생각보다 효..
# 리포트 추출 성공: 중장기 승부주. 그런데, 단기 그림도 긍정적
# 리포트 추출 성공: 전방위 성장모드, 이익률 개선이 관건
# 리포트 추출 성공: 잰 걸음
# 리포트 추출 성공: 아직은 투자의견 유지
# 리포트 추출 성공: 고른 성장의 힘! 향후 페이, 게임즈, 로엔 가..
# 리포트 추출 성공: 본업과 자회사 모두 긍정적
# 리포트 추출 성공: 사업부문별 성장과 시너지 효과
# 리포트 추출 성공: 장기 승부주. 단기적으론 2H17 마케팅비 급증..
# 리포트 추출 성공: 플랫폼의 영향력은 점점 더 커진다
# 리포트 추출 성공: 시작된 광고의 성장과 플랫폼의 힘 확읶
# 리포트 추출 성공: 시장경쟁력 회복에 대한 기대
# 리포트 추출 성공: 탄력이 붙은 광고
# 리포트 추출 성공: 2Q17 실적 호조. 종전 전망치 부합
# 리포트 추출 성공: [2Q17] 광고와 컨텐츠의 고른 성장세
# 리포트 추출 성공: 광고 사업의 지속적인 성장
# 리포트 추출 성공: 투자 유치는 수익화의 신호
# 리포트 추출 성공: 카카오 모빌리티, 5,000억원 규모 투자 유치
# 리포트 추출 성공: 시작된 변화
# 리포트 추출 성공: 카카오뱅크 3Q17 론칭 예상. 흥행요소 다수!!
# 리포트 추출 성공: 광고 부문 변화에 초점
# 리포트 추출 성공: 양호한 실적, 변화의 움직임
# 리포트 추출 성공: 콘텐츠 캐시카우 회복에 신규 사업도 진전
# 리포트 추출 성공: 조금씩 바뀌기 시작
# 리포트 추출 성공: 회수기로 진입! 분기별 이익 모멘텀 갈수록 ..
# 리포트 추출 성공: 1Q17 견조, 전망치 초과. 광고 개선 & O2O 잠..
# 리포트 추출 성공: 예상보다 빠르게 회복 중
# 리포트 추출 성공: 긍정적 변화 감지
# 리포트 추출 성공: 4월 펜타스톰, 6월 카카오뱅크 주목. 장기 O2..
# 리포트 추출 성공: 지분이슈보다는 펀더멘털에 집중
# 리포트 추출 성공: 펜타스톰, 2Q17 카카오 영업이익 기여도 매우..
# 리포트 추출 성공: 단기 2Q 게임 모멘텀 주목. 장기 O2O 잠재력 ..
# 리포트 추출 성공: 알리페이와 손잡다
# 리포트 추출 성공: 하반기에 광고의 반등을 꾀하다
# 리포트 추출 성공: 허물을 벗는 중
# 리포트 추출 성공: 점진적인 개선
# 리포트 추출 성공: 컨텐츠 사업 확장 전략과 카카오프렌즈 IP 가..
# 리포트 추출 성공: 실적 턴어라운드 + 택시, 드라이버 등 O2O 잠..
# 리포트 추출 성공: 새로운 성장에 대한 기대
# 리포트 추출 성공: 전 사업부문에 걸친 긍정적 성과
# 리포트 추출 성공: 새해 주가반등의 의미는?
# 리포트 추출 성공: 다음 앱 이용성 확대에 주목
# 리포트 추출 성공: O2O 잠재력을 바탕으로 한 중장기 다크호스
# 리포트 추출 성공: 콘텐츠 및 커머스의 긍정적 성과
# 리포트 추출 성공: 전진하는 거북이
# 리포트 추출 성공: 조금 더 보여줘야 할 때
# 리포트 추출 성공: O2O 서비스 지표 우수 + 실적, 개선 추이 전..
# 리포트 추출 성공: 적절한 O2O 플랫폼 전략 변화
# 리포트 추출 성공: 3Q16도 상반된 실적 전망
# 리포트 추출 성공: 실적부진 지속, 단기 관망. 중장기 O2O 잠재..
# 리포트 추출 성공: 변곡점을 기다리며...
# 리포트 추출 성공: 조금 더 기다리자
# 리포트 추출 성공: 2Q16 영업이익 부진. But, O2O 서비스 지표 ..
# 리포트 추출 성공: 아쉬운 실적과 Monetization
# 리포트 추출 성공: O2O 수익화를 기다리는 시점
# 리포트 추출 성공: NDR 후기 보고서
# 리포트 추출 성공: 7부 능선
# 리포트 추출 성공: 플레이볼, O2O 본 게임 임박
# 리포트 추출 성공: 아쉬운 광고와 신규 O2O 가능성
# 리포트 추출 성공: 주요 동향 정리 및 업데이트
# 리포트 추출 성공: 램시마 미국 FDA 승인
# 리포트 추출 성공: 6월 O2O 기대감 vs 5월 1Q16 실적발표 불안감..
# 리포트 추출 성공: 기대는 충분, 방점을 찍을 이슈가 필요하다
# 리포트 추출 성공: “Kakao for X” 시작 시점 가시화
# 리포트 추출 성공: 실적은 바닥 확인, 2Q16 O2O 모멘텀 재가동 ..
# 리포트 추출 성공: 광고의 부진, 아쉬운 수익성
# 리포트 추출 성공: 금상첨화(錦上添花)
# 리포트 추출 성공: 카카오, 콘텐츠 Power Up!
# 리포트 추출 성공: 로엔 지분 인수 이슈보다 더 중요한 것은?
# 리포트 추출 성공: 컨텐츠 플랫폼으로서의 경쟁력 강화
# 리포트 추출 성공: 4Q15 Preview: 게임 매출의 회복과 커머스의 ..
# 리포트 추출 성공: 중금리 대출은 거들뿐
# 리포트 추출 성공: 2016년 매분기 신규 O2O 사업 진출
# 리포트 추출 성공: O2O 서비스 확대 본격화 임박
# 리포트 추출 성공: 가슴 졸였던 Preview 시즌, 발표하니 안도감
# 리포트 추출 성공: 새로운 성장에 대한 기대
# 리포트 추출 성공: 신사업 잠재력 풍부. 꿈 많은 장기투자 종목
# 리포트 추출 성공: 돌아온 카톡 게임, 3분기 실적 바닥 확인
# 리포트 추출 성공: 속도의 차이만 있을 뿐, 순방향으로
# 리포트 추출 성공: 실적부진보단 신사업 잠재력을 보자
# 리포트 추출 성공: 몇 년 뒤 어떤 모습일까?
# 리포트 추출 성공: 새로운 가능성
# 리포트 추출 성공: PER 100배 주식을 추천하는 이유
# 리포트 추출 성공: 실적부진을 상쇄하고도 남는 신사업 스토리
# 리포트 추출 성공: 실적부진 vs. 미래 수익 창출 기대감
# 리포트 추출 성공: 단기적인 실적보다 플랫폼 비즈니스 가치를 ..
# 리포트 추출 성공: 세상을 바꾸기 위한 비용
# 리포트 추출 성공: 모멘텀 풍부. 최근 핫이슈 정리 및 업데이트
# 리포트 추출 성공: 미래 성장을 위한 서비스와 트래픽 확보
# 리포트 추출 성공: 신규사업 활발 + Path 양수도는 동남아 시장 ..
# 리포트 추출 성공: 성공적인 M&A로 사업 기회를 열어간다
# 리포트 추출 성공: 실적모멘텀 부재보단 핀테크,   O2O 등 다양..
# 리포트 추출 성공: 주요 신사업 호조. 다양한 사업내용들 긍정적
# 리포트 추출 성공: 성장을 위한 라인업 정비
# 리포트 추출 성공: O2O, 생활 속에 스며들기
# 리포트 추출 성공: 2Q, 카카오택시 타기 좋은 시간
# 리포트 추출 성공: 생각의 크기만큼 보이는 가치
# 리포트 추출 성공: 콜택시보다 30배 큰 대리운전 시장
# 리포트 추출 성공: 전형적인 바닥 시그널 확인
# 리포트 추출 성공: 신규 성장을 위한 투자확대
# 리포트 추출 성공: 카카오톡, 인터넷 전문은행 마케팅 플랫폼으..
# 리포트 추출 성공: 최근 주가부진, 무슨 일들이 있었던 것일까?
# 리포트 추출 성공: 레이븐 영향은 제한적
# 리포트 추출 성공: 상반기 마케팅비 집중 감안, 한 템포 숨고르..
# 리포트 추출 성공: 불가피한 공격적인 투자. 성과만 내주세요
# 리포트 추출 성공: 15년 모바일 성장과 이를 위한 투자확대
# 리포트 추출 성공: 이번  발렌타인데이엔  카카오톡으로  선물을..
# 리포트 추출 성공: 세뱃돈 받고 가세요!
# 리포트 추출 성공: 15년 신규사업 공격적 마케팅 계획은 우려사..
# 리포트 추출 성공: 소셜검색과 핀테크가 핵심 모멘텀
# 리포트 추출 성공: 전자직불 충전한도 폐지, 결제한도 상향은 긍..
# 리포트 추출 성공: 카카오페이 가입자, 가맹점 확보 추이 순항 ..
# 리포트 추출 성공: 모바일 광고 성장 본격화 기대
# 리포트 추출 성공: 다시 담아야할 때
# 리포트 추출 성공: 본격적인 시너지 기대
# 리포트 추출 성공: 3분기 실적은 합병 관련 비용의 영향이 컸다
# 리포트 추출 성공: 3Q Shock 아님. 카카오 광고/결제/커머스 잠..
# 리포트 추출 성공: 빅 배쓰 (Big Bath), 매수 기회
# 리포트 추출 성공: 모바일 히어로 for Kakao
# 리포트 추출 성공: 규제이슈, 오버행 이슈 감안해도 최근 과도한..
# 리포트 추출 성공: 결제사업, 커머스 활성화 및 기타서비스 확장..
# 리포트 추출 성공: 합병시너지와 신규서비스에 대한 기대
# 리포트 추출 성공: 결제와 소매는 게임과 광고보다 크다.
# 리포트 추출 성공: 단기적인 실적보다 합병 이후 그림을 볼때
# 리포트 추출 성공: 2Q 예상 부합. 다음 자체 실적보단 카카오 합..
# 리포트 추출 성공: 하반기부터 많은 것을 보여줄 듯
# 리포트 추출 성공: 잠재력을 예단하지 말라.
# 리포트 추출 성공: 다음-카카오의 미래가 좋아 보이는 이유
# 리포트 추출 성공: 합병 후 사업모델 창출이 관건
# 리포트 추출 성공: 합병비율 산정 시 카카오 가치 과소 평가, 상..
# 리포트 추출 성공: 트래픽과 서비스의 시너지 기대
# 리포트 추출 성공: 조금씩 좋아지는 모습 보여줄 것
# 리포트 추출 성공: 실적흐름은 부진하고 신성장엔진은 안보이고...
# 리포트 추출 성공: 투자포인트를 찾을 수 없는 실적
# 리포트 추출 성공: 탐방 note – 기대보다 더딘 개선
# 리포트 추출 성공: 신성장엔진 돌파구 마련까지는 긴 호흡으로 ..
# 리포트 추출 성공: 하반기부터는 좋아질 것
# 리포트 추출 성공: 투자 지속, 하반기 기대
# 리포트 추출 성공: 2014년 이벤트효과 기대
# 리포트 추출 성공: 실적보단 버즈런처, NIS 등 잠재력 감안한 긴..
# 리포트 추출 성공: 모바일 및 게임 2014년에도 투자 지속
# 리포트 추출 성공: 3Q Review : 모바일플랫폼 전략, 꾸준한 전진
# 리포트 추출 성공: 모바일 투자 지속, 2014년 업황 개선 기대
# 리포트 추출 성공: 투자의 한해 거의 마무리. 이젠 내년을 봐야 ..
# 리포트 추출 성공: 다음이 아니라 지금!
# 리포트 추출 성공: 하반기에도 투자 지속으로 수익성 하락 예상
# 리포트 추출 성공: 공격적 마케팅, 과연 신성장엔진 육성을 이끌..
# 리포트 추출 성공: 낮아지는 가이던스
# 리포트 추출 성공: 2분기 매출 증가, 이익 감소 예상
# 리포트 추출 성공: 아쉽지만 다음을 기약하자
# 리포트 추출 성공: 신사업 투자 성과, 사후적 대응이 현실적이라..
# 리포트 추출 성공: 가시적인 성과가 필요한 시점
# 리포트 추출 성공: 다음은 투자 중
# 리포트 추출 성공: 한 템포 쉬고!
# 리포트 추출 성공: 1Q 구조적 부진. 신성장엔진 발굴/육성/발전 ..
# 리포트 추출 성공: 광고주 증가, 모바일 트래픽 호조세
# 리포트 추출 성공: 기대와 우려 사이
# 리포트 추출 성공: 빠질 만큼 빠졌다. 차분히 신사업 육성과정을..
# 리포트 추출 성공: 만족스런 가이던스, 이를 초과할 가능성도 충..
# 리포트 추출 성공: 오버추어 독립효과는 한시적. 궁극적 성장엔..
# 리포트 추출 성공: 4Q12 Review : 저조한 실적, 컨센서스 수준의..
# 리포트 추출 성공: 검색광고주 증가, 모바일과 게임 강화로 성장..
# 리포트 추출 성공: 4분기실적 보다 광고주 증가에 주목
# 리포트 추출 성공: 자체 검색광고주 확대 중
# 리포트 추출 성공: 예상보다 빠르게 좋아지고 있는 중
# 리포트 추출 성공: 오버추어 독립은 긍정적. 관건은 모바일 사업..
# 리포트 추출 성공: 2위 사업자가 누릴 수 있는 행복
# 리포트 추출 성공: 단기적인 어닝모멘텀 약화 예상
# 리포트 추출 성공: 실적 부진(성장둔화 추이) + 신성장 모멘텀 ..
# 리포트 추출 성공: 모바일 성과가 필요한 시점
# 리포트 추출 성공: 다음, 오버추어와의 결별보다 광고 경기 둔화..
# 리포트 추출 성공: 오버추어 결별효과 영향은 제한적. 다만 불확..
# 리포트 추출 성공: 3분기 실적 시장컨센서스 수준 전망
# 리포트 추출 성공: 다음-모바게, 드디어 성과를 나타내다!
# 리포트 추출 성공: 비용절감 효과 하반기에도 지속 전망
# 리포트 추출 성공: 긴 호흡 필요
# 리포트 추출 성공: 기대보다 좋아질 부분이 많다! 검색광고, 모..
# 리포트 추출 성공: 포털주 우려에서 자유롭지 않다
# 리포트 추출 성공: 검색광고 플랫폼 결정과 신규사업 성과에 주..
# 리포트 추출 성공: 모바일검색 경쟁력 회복 중
# 리포트 추출 성공: 하반기에는 좋은 일만 생길 것 같아
# 리포트 추출 성공: 2Q12 Preview & 투자포인트 점검
# 리포트 추출 성공: 10만원 마저? 과도한 하락!
# 리포트 추출 성공: 2분기부터는 조금씩 회복되는 모습 보일 것
# 리포트 추출 성공: 1분기 실적 시장컨센서스 하회
# 리포트 추출 성공: 하반기를 기약하자
# 리포트 추출 성공: 1Q12 Review & 주요 포인트 점검
# 리포트 추출 성공: 오버츄어와의 재계약으로 검색 광고 수익성 ..
# 리포트 추출 성공: 낮아진 눈높이는 맞추다
# 리포트 추출 성공: 1분기 실적 시장컨센서스 하회 전망
# 리포트 추출 성공: 1Q 실적보다 더 주목해야 할 것들은?
# 리포트 추출 성공: 1분기보다는 2분기. 상반기보다는 하반기가 ..
# 리포트 추출 성공: 신규 사업의 성공이 성장의 새로운 열쇠
# 리포트 추출 성공: 인터넷업종 내 가장 저평가된 기업
# 리포트 추출 성공: 다소 주춤한 실적, 2분기부터 본격 상승할 것
# 리포트 추출 성공: 2Q12 진입 전후 주가 모멘텀 강화 전망
# 리포트 추출 성공: 다음 모바게 Coming Soon...
# 리포트 추출 성공: 기존사업과 신규사업의 동반성장
# 리포트 추출 성공: 비용 증가보다는 신사업 가시화에 관심을 가..
# 리포트 추출 성공: 실적 개선은 지속되고 배당 성향은 높아지고
# 리포트 추출 성공: 12년 신사업 대호조 지속, 게임부문 대약진 ..
# 리포트 추출 성공: 2012년 다양한 모멘텀 보유
# 리포트 추출 성공: 다음과 DeNA의 제휴로 예상되는 긍정적 영향
# 리포트 추출 성공: 양호한 실적과 밸류에이션 매력
# 리포트 추출 성공: 3분기 실적을 바닥으로 다시 상승하는 모습 ..
# 리포트 추출 성공: 2012년 기업가치 확대 지속 전망
# 리포트 추출 성공: 3Q Good, 4Q Better + 신사업 호조
# 리포트 추출 성공: 신규 사업과 기존 사업간의 균형이 관건
# 리포트 추출 성공: 검색 광고 우려, Too Much!
# 리포트 추출 성공: 4분기와 2012년, 좋아질 일만 남았다
# 리포트 추출 성공: 4분기부터는 기대해도 좋다
# 리포트 추출 성공: 실적보단 신사업 모멘텀
# 리포트 추출 성공: 2Q Review : 포털은 마케팅 전쟁 중
# 리포트 추출 성공: 검색광고 외에도 볼 것이 많다
# 리포트 추출 성공: 신규 비즈니스에 대한 빠른 대응
# 리포트 추출 성공: SNG 투자로 모바일 영향력 강화되고 수익원도..
# 리포트 추출 성공: 신사업 매출 가시화로 기업가치 확대 지속 전..
# 리포트 추출 성공: 모바일 잠재 시장에 거는 기대
# 리포트 추출 성공: 예상 범위 내의 2분기 실적 전망
# 리포트 추출 성공: 긍정적 숨고르기, 즉 신사업 모멘텀 축적 중
# 리포트 추출 성공: 1Q Review : 흠 잡을데 없는 실적과 장기 비..
# 리포트 추출 성공: 오버추어 이슈 일단락. 차기모멘텀 축적 시간..
# 리포트 추출 성공: 광고도 3 Screen 시대
# 리포트 추출 성공: 실적 호조세 지속될 전망
# 리포트 추출 성공: 비용 control만 된다면, 가파른 성장세 지속..
# 리포트 추출 성공: 본원적 경쟁력 상승으로 기업가치 확대 지속 ..
# 리포트 추출 성공: 오버추어 우려 소멸, 고성장, 저평가
# 리포트 추출 성공: 실적과 매체력의 2중주
# 리포트 추출 성공: 밸류에이션 디스카운트 요인 해소되고 실적도..
# 리포트 추출 성공: 네이버 부럽지 않은 네이트 제휴
# 리포트 추출 성공: 2010년에 이어 2011년에도...
# 리포트 추출 성공: 기업가치에 비해 여전히 저평가 상태
# 리포트 추출 성공: 꾸준한 실적 개선으로 밸류에이션 메리트 유..
# 리포트 추출 성공: 강화되고 있는 성장엔진
# 리포트 추출 성공: 4Q10 review - 불확실성 해소와 신규사업 가..
# 리포트 추출 성공: 올 한해도 즐겁다
# 리포트 추출 성공: 오버추어 우려 해소, 고성장, 저평가
# 리포트 추출 성공: 검색광고 불확실성 해소로 밸류에이션 메리트..
# 리포트 추출 성공: 몇가지 흥미로운 시그널들
# 리포트 추출 성공: 오버추어 PPC 변화 미미, 쇼핑하우 단가 인상
# 리포트 추출 성공: 매출도 늘고, 비용도 늘고…
# 리포트 추출 성공: 2011년 오버추어 PPC 하락 소폭에 그칠 전망
# 리포트 추출 성공: 전체 사업영역의 고른 성장세 지속
# 리포트 추출 성공: 리스크는 이미 충분히 반영되어 있다
# 리포트 추출 성공: 오버추어 우려 과도. 저가매수 기회
# 리포트 추출 성공: 3Q Review : 양호한 실적, 4분기보다 내년이 ..
# 리포트 추출 성공: 4분기 어닝서프라이즈 시현할 전망
# 리포트 추출 성공: NHN 대비 PER 격차 축소 바람직
# 리포트 추출 성공: 제휴광고 매출 변동성 두려워할 필요 없다
# 리포트 추출 성공: 3분기 좋고 4분기는 더 좋을 것이다
# 리포트 추출 성공: 4Q 실적모멘텀 주목. DA 단가인상 + 성수기
# 리포트 추출 성공: 트래픽의 Monetization 다각화 전망
# 리포트 추출 성공: 절대적인 저평가 상태인 펀드멘탈에 초점을 ..
# 리포트 추출 성공: 제휴매출 감소에도 실적 개선세 이어질 전망
# 리포트 추출 성공: 과도한 저평가 상태, 적극적 대응 시점
# 리포트 추출 성공: 오버추어 우려 과도, 라이코스 매각 Good
# 리포트 추출 성공: PER 밴드 하단 하향 이탈한 저평가국면
# 리포트 추출 성공: 인터넷업종 내 어닝모멘텀 가장 강할 전망
# 리포트 추출 성공: 높아진 Valuation 매력에 중장기적 관심 필요
# 리포트 추출 성공: 3Q 숨고르기 후 4Q 다시 대폭 개선
# 리포트 추출 성공: 경쟁사의 오버추어 계약 변경 효과는 제한적
# 리포트 추출 성공: 성장성, 안정성 확보. NHN과 동일한 PER 적용..
# 리포트 추출 성공: 실적 호조와 낮아진 검색 광고 리스크
# 리포트 추출 성공: 리스크와 가능성 그리고 M&A
# 리포트 추출 성공: 목표주가 110,000원으로 11% 상향 조정
# 리포트 추출 성공: 시장점유율 확대로 2분기 어닝서프라이즈 예..
# 리포트 추출 성공: 실적만으로도 OK. 모바일 등은 보너스
# 리포트 추출 성공: 어닝 서프라이즈, 수익성 레벨업
# 리포트 추출 성공: 2010년 인터넷업종 내 어닝모멘텀 가장 강할 ..
# 리포트 추출 성공: 투자없는 성장은 없다
# 리포트 추출 성공: 1Q보다 2Q 기대감이 작용하는 타이밍
# 리포트 추출 성공: 온라인광고 시장 확대 수혜 예상
# 리포트 추출 성공: 양호한 4분기 실적 vs 비용 증가 우려
# 리포트 추출 성공: 주가 한단계 더 레벨업 기대
# 리포트 추출 성공: 인터넷업체 중 성장잠재력이 가장 높을 전망
# 리포트 추출 성공: 오버추어 효과, 경기회복 효과, 모바일 잠재..
# 리포트 추출 성공: 1분기에 최고의 실적 모멘텀 예상
# 리포트 추출 성공: 오버추어 효과 및 경기회복 효과 가속화 확인
# 리포트 추출 성공: 2010년 실적 추가 상향 조정
# 리포트 추출 성공: 2010년 경기회복, 오버추어 효과 주목
# 리포트 추출 성공: 뉴스에 안 파셔도 됩니다
# 리포트 추출 성공: 2010년 본원적 경쟁력 상승으로 어닝 서프라..
# 리포트 추출 성공: 3Q 예상보단 양호 전망 + 2010년 개선 기대감
# 리포트 추출 성공: 검색광고 대행사 변경 가시화, 어두운 과거에..
# 리포트 추출 성공: 2010년 어닝 서프라이즈 예상
# 리포트 추출 성공: 09 3Q 부진보다 2010년 개선 기대감 우위
# 리포트 추출 성공: Earning momentum 강화 대비해야 하는 시점
# 리포트 추출 성공: 09 2Q Surprise, 5만원대 적정주가 정당화
# 리포트 추출 성공: 하반기부터 실적 회복 속도 가속화될 전망
# 리포트 추출 성공: No. 2가 변하고 있다
# 리포트 추출 성공: 매수 시점 다음이 아닌 지금
# 리포트 추출 성공: 공격적 실적추정 및 Multiple 적용해도 현재..
# 리포트 추출 성공: 2분기부터 실적 회복국면 본격 진입 전망
# 리포트 추출 성공: 어닝모멘텀 회복에는 시간이 걸릴 것으로 전..
# 리포트 추출 성공: 경기침체에 취약한 매출구조 + 불안정한 영업..
# 리포트 추출 성공: 1분기에 3가지(경기, 영업력, 지분법) 바닥 ..
# 리포트 추출 성공: 구글 코리아 구조 조정은 장기 대형 호재
# 리포트 추출 성공: 09 1Q 대폭 부진, 09 2Q 회복도 제한적일 전..
# 리포트 추출 성공: Spring Effect? 주가와 실적의 방향성 변화 ..
# 리포트 추출 성공: 디스플레이 광고 매출 정체, 어닝모멘텀 회복..
# 리포트 추출 성공: 경기침체 영향 현실화. 어두운 터널의 초입부
# 리포트 추출 성공: 어려운 시기, 2009년 역성장 예상
# 리포트 추출 성공: 08 4Q 예상보다 부진 전망. 09년 경기침체 영..
# 리포트 추출 성공: 경기 침체로 어닝모멘텀 회복에는 시간이 걸..
# 리포트 추출 성공: 09년 경기침체에 따른 성장성 제한 요인 감안..
# 리포트 추출 성공: 불황의 그늘 vs. M&A 이슈
# 리포트 추출 성공: 3Q 실적발표 후 4Q 실적 개선 기대감으로 의..
# 리포트 추출 성공: 지나친 조정, 저평가. 그러나, 08 3Q 실적발..
# 리포트 추출 성공: 경기 둔화로 광고 단가 인하 압력과 광고주 ..
# 리포트 추출 성공: 3분기 검색부문 매출 확대에 힘입어 실적 호..
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# ...
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
# 리포트 추출 성공: 2008년 어닝모멘텀 확대에 주목할 시기!
# 리포트 추출 성공: Microsoft의 Yahoo 인수 제의, 2위 포털에 대..
# 리포트 추출 성공: 12일 연속 외국인 순매수 기록
# 리포트 추출 성공: 4분기 실적 발표가 기대되는 3가지 이유
# 리포트 추출 성공: NHN 주가 급락에 따른 상대적 밸류에이션 매..
# 리포트 추출 성공: 트래픽은 실적을 여는 열쇠
# 리포트 추출 성공: 트래픽 증가에 이은 실적 개선 예상
# 리포트 추출 성공: 다음 트래픽에서 조중동 기사 비중은 0.4%
# 리포트 추출 성공: 규제 리스크보다는 검색경쟁력 강화에 주목
# 리포트 추출 성공: ‘아고라’ 신드롬 지속 가능한가?
# 리포트 추출 성공: 성장과 수익성 관련 불확실성 해소, 3가지 주..
# 리포트 추출 성공: 1분기 실적 악화 주가에 선반영, 2분기 실적 ..
# 리포트 추출 성공: 마지막 승부, 수익성보다 경쟁력에 포커스
# 리포트 추출 성공: 1 분기 실적부진은 저가매수 기회
# 리포트 추출 성공: 이제는 2Q 이후를 보아야 할 때. 저가매수 타..
